# %%
import pandas as pandas
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import xarray as xr 
from xclim import sdba 
import os
# Out:
# c:\Users\ADAPA SUNIL KUMAR\Climate_Downscaling_Project\climate_downscaling\Lib\site-packages\xclim\sdba.py:12: UserWarning: The `xclim.sdba` module has been split into its own package `xsdba`. Users are encouraged to use `xsdba` directly. For the time being, `xclim.sdba` will import `xsdba` to allow for API compatibility. This behaviour may change in the future. For more information, see: https://xsdba.readthedocs.io/en/stable/xclim_migration_guide.html
#   warnings.warn(

# %%
#bias correction :
import xarray as xr

# Path to your NetCDF file
file_path = r"C:\Users\ADAPA SUNIL KUMAR\Climate_Downscaling_Project\data\temperature_Gcm_data\observed_data\IMD_AVERAGE_TEMP_0.25\IMD_1975_avg_temp_0.25.nc"

# Open the dataset
ds = xr.open_dataset(file_path)

# %%
ds
# Out:
# <xarray.Dataset> Size: 51MB
# Dimensions:    (time: 365, LATITUDE: 129, LONGITUDE: 135)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 1975-01-01 1975-01-02 ... 1975-12-31
#   * LATITUDE   (LATITUDE) float64 1kB 6.5 6.75 7.0 7.25 ... 38.0 38.25 38.5
#   * LONGITUDE  (LONGITUDE) float64 1kB 66.5 66.75 67.0 ... 99.5 99.75 100.0
# Data variables:
#     avg_temp   (time, LATITUDE, LONGITUDE) float64 51MB ...
# Attributes:
#     tmin:     -3.554999828338623
#     tmax:     38.81999969482422

# %%
file_path = r"C:\Users\ADAPA SUNIL KUMAR\Climate_Downscaling_Project\data\temperature_Gcm_data\INM-CM4-8_YEARLY-TEMP-DATA\INM-CM4-8_1975.nc"
ds2 = xr.open_dataset(file_path)

# %%
ds2
# Out:
# <xarray.Dataset> Size: 25MB
# Dimensions:  (time: 365, lat: 129, lon: 135)
# Coordinates:
#   * time     (time) datetime64[ns] 3kB 1975-01-01 1975-01-02 ... 1975-12-31
#   * lat      (lat) float32 516B 6.5 6.75 7.0 7.25 7.5 ... 37.75 38.0 38.25 38.5
#   * lon      (lon) float32 540B 66.5 66.75 67.0 67.25 ... 99.25 99.5 99.75 100.0
# Data variables:
#     data     (time, lat, lon) float32 25MB ...

# %%
ds.info
# Out:
# <bound method Dataset.info of <xarray.Dataset> Size: 51MB
# Dimensions:    (time: 365, LATITUDE: 129, LONGITUDE: 135)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 1975-01-01 1975-01-02 ... 1975-12-31
#   * LATITUDE   (LATITUDE) float64 1kB 6.5 6.75 7.0 7.25 ... 38.0 38.25 38.5
#   * LONGITUDE  (LONGITUDE) float64 1kB 66.5 66.75 67.0 ... 99.5 99.75 100.0
# Data variables:
#     avg_temp   (time, LATITUDE, LONGITUDE) float64 51MB ...
# Attributes:
#     tmin:     -3.554999828338623
#     tmax:     38.81999969482422>

# %%
ds2.info
# Out:
# <bound method Dataset.info of <xarray.Dataset> Size: 25MB
# Dimensions:  (time: 365, lat: 129, lon: 135)
# Coordinates:
#   * time     (time) datetime64[ns] 3kB 1975-01-01 1975-01-02 ... 1975-12-31
#   * lat      (lat) float32 516B 6.5 6.75 7.0 7.25 7.5 ... 37.75 38.0 38.25 38.5
#   * lon      (lon) float32 540B 66.5 66.75 67.0 67.25 ... 99.25 99.5 99.75 100.0
# Data variables:
#     data     (time, lat, lon) float32 25MB ...>
